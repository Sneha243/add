# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha243/add/blob/module4/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###pyplot
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
ypoints = np.array([84,79,80,86,92,89])
plt.plot(xpoints, ypoints)
plt.show()

# %%
###Plotting1
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
ypoints = np.array([84,79,80,86,92,89])

plt.plot(xpoints, ypoints)
plt.show()

# %%
###Plotting2
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
ypoints = np.array([84,79,80,86,92,89])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
###Plotting3
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
ypoints = np.array([84,79,80,86,92,89])

plt.plot(xpoints, ypoints)
plt.show()

# %%
###plotting4
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints)
plt.show()

# %%
###markers1
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
###markers2
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, marker = '*')

# %%
#####markers3
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
###markers4
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
###markers5
import matplotlib.pyplot as plt
import numpy as np


plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
###markers6
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
###markers7
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
###markers8
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
###markers9
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %%
###lines1
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
###lines2
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
###lines3
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, ls = ':')
plt.show()

# %%
###lines4
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
###lines5
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, c = '#4CAF50')
plt.show()

# %%
###lines6
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([84,79,80,86,92,89])
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
###labels1
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.plot(x, y)

plt.xlabel("subjects")
plt.ylabel("marks")

plt.show()

# %%
###labels2
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])
plt.plot(x, y)

plt.title("student marks")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.show()

# %%
###labels3
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("student marks", fontdict = font1)
plt.xlabel("subjects", fontdict = font2)
plt.ylabel("marks", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
###labels4
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.title("student marks", loc = 'left')
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)
plt.show()

# %%
###grid1
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.title("student marks")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
###grid2
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.title("student marks")
plt.xlabel("subjects")
plt.ylabel("marks")


plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
###grid3
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.title("student marks")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
###grid4
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.title("student marks")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
###subplot1
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([94,76,89,78,84,92])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
###subplot2
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([94,76,89,78,84,92])
plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
###subplot3
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
###subplot4
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([94,76,89,78,84,92])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
###subplot5
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("sneha")

#plot 2:
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([94,76,89,78,84,92])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("sreya")

plt.suptitle("student marks")
plt.show()

# %%
###scatter1
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.scatter(x, y)
plt.show()

# %%
###scatter2
import matplotlib.pyplot as plt
import numpy as np

#sneha
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])
plt.scatter(x, y)

#sreya
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([94,76,89,78,84,92])
plt.scatter(x, y)

plt.show()

# %%
###scatter3
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

plt.scatter(x, y, color = 'hotpink')
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([94,76,89,78,84,92])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
##scatter4
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])
colors = np.array(["red","green","blue","yellow","pink","black"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
##scatter5
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

colors = np.array([0, 10, 20, 30, 40, 45])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
###scatter6
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])

colors = np.array([0, 10, 20, 30, 40, 45])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
###scatter7
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])
sizes = np.array([20,50,100,200,500,1000])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
###scatter8
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([84,79,80,86,92,89])
sizes = np.array([1000,60,90,10,300,600])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
###scatter9
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
###bar1
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.bar(x,y)
plt.show()

# %%
###bar2
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.barh(x, y)
plt.show()

# %%
###bar3
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.bar(x, y, color = "red")
plt.show()

# %%
###bar4
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
###bar5
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
###bar6
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
###bar7
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011'])
y = np.array([48,79,80,26,53,89,])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
###histogram1
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(78,82,94)

plt.hist(x)
plt.show()

# %%
###histogram2
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
###piechart1
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86,92,89])

plt.pie(y)
plt.show()

# %%
###piechart2
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86,92,89])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011']

plt.pie(y, labels = mylabels)
plt.show()

# %%
##piechart3
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86,92,89])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011']

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
###piechart4
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86,92,89])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011']
myexplode = [0.2, 0, 0, 0,0,0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
###piechat5
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86,92,89])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011','MATH1001','MATH1011']
myexplode = [0.2, 0, 0, 0,0,0]


plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
###piechart6
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011']
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
###piechart6
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011']

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
###piechart7
import matplotlib.pyplot as plt
import numpy as np

y = np.array([84,79,80,86])
mylabels = ['CLAD1001','CHEM1001','CSEN1001','CSEN1011']

plt.pie(y, labels = mylabels)
plt.legend(title = "subjecr marks:")
plt.show()
